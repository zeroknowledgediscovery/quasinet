# %%
#from quasinet.curvature import compute_metric_tensor, compute_curvature
from quasinet.qnet import load_qnet
from quasinet.zqnet import zQnet

# %%
model=load_qnet('melanoma_model.gz')

# %%
import pandas as pd
datapath='melanoma_cases.csv'
dataall=pd.read_csv(datapath,index_col=0,keep_default_na=False,
                               na_filter= False,dtype='str').fillna('').reindex(columns=model.feature_names).fillna('H')
S=dataall.values
s=S[10]

# %%
# %%time
#seq is None by default which looks at perturbations around teh null seq. Can replace with other sequences
zf=model.zshap(m=30,seq=None)
# Out:
# symmetric case
# CPU times: user 52min 22s, sys: 57.9 s, total: 53min 20s
# Wall time: 10min 40s

# %%
# %%time
zsf=model.personal_zshap(s)
# Out:
# CPU times: user 22.9 s, sys: 33.7 ms, total: 22.9 s
# Wall time: 23.8 s

# %%
zsf.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
zf.plot(kind='barh')
# Out:
# <AxesSubplot:>
